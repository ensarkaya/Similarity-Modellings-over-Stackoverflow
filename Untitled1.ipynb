# %% [markdown]
# <a href="https://colab.research.google.com/github/ensarkaya/CS425-Group7-TermProject/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd

path = '1bin.csv'
df = pd.read_csv(path)

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

dummy =["and","or","is","are","what","where","who","whom","when","in"
            ,"a","an","of","to","for","from","by","can","i","with","its",
             "there","that","thats","all","does","do","did","the","am","using",
             "trying","how","be","not","doesn't","don't","didn't","won't","will",
             "my","be","should","would","as","use","must","have","but","however",
             "another","other","one","two","three","four","five","still","on","why","it"
              ,"how","a","to","why"]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df.head(12)
# Out:
#           id                                              title  \
# 0   51469083                     Admob banner ad best practices
# 1   48641591  scale in CSS3 keyframes can't work well on SVG...
# 2   50836071                   python : function type parameter
# 3   51913237                    Getting TEntity type in logging
# 4   49214964                           Strange PHP array syntax
# 5   50467709  Wordpress multisite - getting data from wp_sit...
# 6   48789078  How to make virtual video port, direct it to a...
# 7   48392370            Docker Enviroment Variable not working?
# 8   49686963  How to get Local Base Path Selected `Folder` u...
# 9   52071015  Outputstream start writing when inputstream st...
# 10  49428259                           svg.js with existing svg
# 11  50620344               Display 0x00-0x1F characters in font
#
#                                                  tags  answer_count  score  \
# 0                              ios|swift|google-admob             2      0
# 1                                      css3|svg|scale             1      0
# 2                             python|types|parameters             1      1
# 3         c#|.net|entity-framework|entity-framework-6             1      0
# 4                                                 php             0      0
# 5               wordpress|wordpress-theming|multisite             1      0
# 6   java|video-streaming|driver|hardware|virtualiz...             0      1
# 7                             command-line|dockerfile             1      0
# 8                      javascript|jquery|node.js|file             0      0
# 9                           java|web|io|jersey-client             1      1
# 10                                         svg|svg.js             1      0
# 11                            c#|winforms|fonts|ascii             1      1
#
#     view_count  comment_count
# 0           49              0
# 1           87              2
# 2           64              6
# 3           51              0
# 4           23              0
# 5           41              1
# 6          142              0
# 7           62              0
# 8           35              6
# 9           62              0
# 10         555              0
# 11         253              5

# %%
df["title"] = df["title"].apply(lambda x: x.lower())
stop = stopwords.words('english')
stop.append(dummy)

df["title"] = df["title"].str.split(' ').apply(lambda x: ' '.join(k for k in x if k not in stop))
df.head(12)
# Out:
#           id                                              title  \
# 0   51469083                     admob banner ad best practices
# 1   48641591      scale css3 keyframes can't work well svg path
# 2   50836071                   python : function type parameter
# 3   51913237                       getting tentity type logging
# 4   49214964                           strange php array syntax
# 5   50467709     wordpress multisite - getting data wp_sitemeta
# 6   48789078  make virtual video port, direct avd emulator p...
# 7   48392370                docker enviroment variable working?
# 8   49686963  get local base path selected `folder` using fi...
# 9   52071015  outputstream start writing inputstream starts ...
# 10  49428259                                svg.js existing svg
# 11  50620344                  display 0x00-0x1f characters font
#
#                                                  tags  answer_count  score  \
# 0                              ios|swift|google-admob             2      0
# 1                                      css3|svg|scale             1      0
# 2                             python|types|parameters             1      1
# 3         c#|.net|entity-framework|entity-framework-6             1      0
# 4                                                 php             0      0
# 5               wordpress|wordpress-theming|multisite             1      0
# 6   java|video-streaming|driver|hardware|virtualiz...             0      1
# 7                             command-line|dockerfile             1      0
# 8                      javascript|jquery|node.js|file             0      0
# 9                           java|web|io|jersey-client             1      1
# 10                                         svg|svg.js             1      0
# 11                            c#|winforms|fonts|ascii             1      1
#
#     view_count  comment_count
# 0           49              0
# 1           87              2
# 2           64              6
# 3           51              0
# 4           23              0
# 5           41              1
# 6          142              0
# 7           62              0
# 8           35              6
# 9           62              0
# 10         555              0
# 11         253              5
