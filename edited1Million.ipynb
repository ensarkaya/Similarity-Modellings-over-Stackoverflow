# %% [markdown]
# <a href="https://colab.research.google.com/github/ensarkaya/CS425-Group7-TermProject/blob/master/edited1Million.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
from collections import defaultdict
import nltk
from nltk.corpus import stopwords
path = '1bin.csv'
df = pd.read_csv(path)
nltk.download('stopwords')
dummy =["and","or","is","are","what","where","who","whom","when","in"
            ,"a","an","of","to","for","from","by","can","i","with","its",
             "there","that","thats","all","does","do","did","the","am","using",
             "trying","how","be","not","doesn't","don't","didn't","won't","will",
             "my","be","should","would","as","use","must","have","but","however",
             "another","other","one","two","three","four","five","still","on","why","it"
              ,"how","a","to","'",".",",",";",":","?","!","-","_","1","2","3","4","5","6","7","8","9","0"]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df["title"] = df["title"].apply(lambda x: x.lower())
stop = stopwords.words('english')
stop.append(dummy)

df["title"] = df["title"].str.split(' ').apply(lambda x: ' '.join(k for k in x if k not in dummy))

dic = {}
def has_key_with_some_values(d, key):
    return d.has_key(key) and d[key]
def get_values_if_any(d, key):
    return d.get(key, [])
for i in range(1000):
  str = df.loc[i,'title'].split()
  for j in range(len(str)):
    while len(str[j]) > 0 and (str[j][0] < 'a' or str[j][0] > 'z') and (str[j][0] < '0' or str[j][0] > '9') and str[j][0] != '#' and str[j][len(str[j])-1] != '+':
      str[j] = str[j][1:]
    while len(str[j]) > 0 and (str[j][len(str[j])-1] < 'a' or str[j][len(str[j])-1] > 'z') and (str[j][len(str[j])-1] < '0' or str[j][len(str[j])-1] > '9') and str[j][len(str[j])-1] != '#' and str[j][len(str[j])-1] != '+':
      str[j] = str[j][:len(str[j])-2]
      
    
    if str[j] in dic:
      dic[str[j]].append(df.loc[i,'id'])
    else:
      dic[str[j]]=[df.loc[i,'id']]
# print(dic['java'][0])
dic2={}
dic3 = {}
for i in dic:
#   print(i)
  count=0
  #keys = df.loc[i,'title']
  for j in dic[i]:
    count+=1
    #if id in dic3:
     # dic3[id].append(keys)
    #else:
     # dic3[id] = [keys]
    
  dic2[i]=count
#   print(i," **** ", count)
  if count > 2:
    for j in range(count):
      id = dic[i][j] 
      if id in dic3:
        dic3[id].append(i)
      else:
        dic3[id] = [i]
  
#   if count<5:
#     if i != "":
#       for k in dic[i]:
#         print(i,": ",count,", k: ",k)
for i in dic3:
  print(i," : ",dic3[i])
# Out:
# 51469083  :  ['best']
# 51378425  :  ['best', 'java', 'project', 'eclipse']
# 48914389  :  ['best', 'docker', 'images']
# 51848940  :  ['best', 'header', 'api', 'information']
# 52062981  :  ['best', 'android', 'way', 'ap']
# 48565913  :  ['best', 'way']
# 48641591  :  ["can't", 'work', 'svg', 'path']
# 51497025  :  ["can't", 'which', 'line', 'error', 'code', 'gives', 'me', 'more']
# 50813786  :  ["can't", 'mongodb', 'test', 'load', 'find']
# 51074292  :  ["can't", 'display', 'items']
# 49740666  :  ["can't", 'error', 'files', 'apache', 'django', 'upload']
# 51025944  :  ["can't", 'data', 'data', 'grid', 'pass', 'same', 'controller', 'at', 'time', 'view']
# 51033054  :  ["can't", 'characters', '', 'maps', 'character', 'position']
# 49710969  :  ["can't", 'json']
# 52117241  :  ['work', 'browser', 'button', 'click', 'c#']
# 51120939  :  ['work']
# 50778121  :  ['work', 'if', 'key', 'query', 'partition', 'set', 'even']
# 49163668  :  ['work', 'script', 'code', 'menu', 'within', 'fil', 'external']
# 50367394  :  ['work', 'running', 'javascript', 'functions']
# 49791079  :  ['work', 'image', 'javascript']
# 49941310  :  ['work', 'hit', 'way', 'stop']
# 51422747  :  ['work', '', '', 'valu', 'task', 'return']
# 51115267  :  ['work', '', 'javascript', 'me']
# 49863002  :  ['work', 'file', 'css', 'js']
# 50010717  :  ['work']
# 48316830  :  ['work', 'this']
# 51922888  :  ['work', 'while', 'java']
# 49428259  :  ['svg']
# 50921039  :  ['svg', 'css', 'working', 'chrome']
# 49686963  :  ['path', 'file', 'get', 'local', 'selected', 'folde', 'browser']
# 49132443  :  ['path', 'getting', 'field', 'elements', 'html', 'after', 'page', 'values']
# 51632954  :  ['path']
# 51283731  :  ['path', 'spring', 'files', 'folder', 'boot', 'resources']
# 49201281  :  ['path', 'error']
# 49634471  :  ['path', 'python', 'import', 'see', 'module']
# 50175014  :  ['path', 'file', 'i', 'get', 'running']
# 50296775  :  ['path', 'make', 'file']
# 50836071  :  ['python', 'function', 'type', 'parameter']
# 50787091  :  ['python', 'index']
# 51114820  :  ['python', 'function', 'at']
# 51712128  :  ['python', 'working', 'expected', 'inheritance']
# 49392032  :  ['python', 'retrieve', 'web']
# 51425129  :  ['python', 'function', 'error', 'rows', 'pandas', 'passing', 'giving']
# 49799405  :  ['python', 'problems', 'module', 'install']
# 51184089  :  ['python', 'file', 'reading', 'log']
# 52071642  :  ['python', 'files', 'copying', 'include']
# 51808725  :  ['python', 'connect', 'unable']
# 50174352  :  ['python', 'text', 'machine']
# 49126777  :  ['python']
# 51261827  :  ['python', 'code']
# 50783655  :  ['python', 'user', 'based', 'next', 'key', 'action', 'show']
# 51044122  :  ['python', 'function', 'around']
# 50454470  :  ['python', 'array', 'make', 'list', 'unable']
# 48809849  :  ['function', 'angular', 'build']
# 48571948  :  ['function', 'format']
# 48126777  :  ['function', 'error']
# 51351020  :  ['function', 'javascript', 'execution']
# 49353995  :  ['function', 'through', 'reverse', 'c', 'finding']
# 50426005  :  ['function', 'pass']
# 49706992  :  ['function', 'type', 'complex', 'returns']
# 51609719  :  ['function', 'correct', 'window']
# 51084055  :  ['function', 'element', 'jquery', 'custom', 'disable']
# 51237639  :  ['function', 'variable', 'after', 'jquery', 'has', 'was', 'run']
# 48114599  :  ['function', 'this']
# 48193026  :  ['function', 'creation', 'object', 'scope']
# 50899743  :  ['function', 'r', 'out']
# 48712821  :  ['function', 'javascript', 'out', 'call', 'variables']
# 49366420  :  ['function', 'center']
# 49344011  :  ['function', 'reverse']
# 48381085  :  ['function', 'code', 'read', 'library', 'pandas', 'source', 'possible']
# 51667739  :  ['function', 'virtual', 'table', 'c', 'without', 'reference', 'pointer']
# 48146499  :  ['function', 'calling']
# 51465129  :  ['function', 'function', 'data', 'frame']
# 48775762  :  ['function', 'typeerro']
# 48572734  :  ['function', 'function', 'type', 'type', 'object', 'binding', 'possible']
# 50215807  :  ['function', 'class', 'cannot', 'call']
# 51208751  :  ['function', 'which', 'loops', 'async']
# 48861514  :  ['function', 'implement', 'different', 'pytho', 'argument', 'types']
# 51913237  :  ['type', 'getting']
# 50233463  :  ['type', 'getting', 'value', 'date', 'erro', 'cannot', 'dat']
# 49287418  :  ['type', 'type', 'cannot', 'has', 'no', 'expression', 'call', 'call']
# 48534130  :  ['type', 'data', 'used']
# 50216346  :  ['type', 'angular', 'dynamic', 'input', 'checkbox']
# 50448678  :  ['type', 'line', 'error', 'google', 'chart']
# 48068855  :  ['type', 'create', 'render', 'this', 'memory']
# 50953658  :  ['type', 'i', 'property']
# 49745483  :  ['parameter', 'laravel', 'request', 'validation', 'pass']
# 48425712  :  ['parameter', 'variable', 'output', 'shell', 'oracle', 'package']
# 49082473  :  ['parameter']
# 50404124  :  ['parameter', 'pass']
# 50072203  :  ['parameter', 'input', 'take', 'pointer']
# 48612019  :  ['parameter', 'pass', 'component']
# 49274867  :  ['parameter', 'which', 'page', 'add', 'class', 'passing', 'item']
# 50467709  :  ['getting', 'data']
# 48904254  :  ['getting', 'php', 'error', 'code', 'user', 'at']
# 50159427  :  ['getting', 'after', 'project', 'copying', 'server', 'screen']
# 48083510  :  ['getting', 'file', 'text', 'text']
# 48534247  :  ['getting', 'image', 'reverse']
# 51920742  :  ['getting', 'strange', 'cannot', 'load', 'execution', 'reference']
# 50801315  :  ['getting', 'error', 'query', 'oracle']
# 50164761  :  ['getting', 'child']
# 50194174  :  ['getting', 'firebas']
# 48241572  :  ['getting', 'value', 'class', 'javascript', 'same', 'div']
# 48281801  :  ['getting', 'image', 'taking']
# 49482413  :  ['getting', 'at']
# 48419916  :  ['getting', 'javascript', 'results', 'desired']
# 49214964  :  ['strange', 'php', 'array']
# 51222975  :  ['strange', '', 'code', 'unable', 'scala']
# 48752075  :  ['php', 'php', 'array', 'get', 'duplicate', 'items', 'objects']
# 51286980  :  ['php', 'script', 'link', 'working', 'inside']
# 48473901  :  ['php', 'display', 'fetch', 'results']
# 50636685  :  ['php', 'lines', 'fil', 'random']
# 48869326  :  ['php', 'remove', 'json', 'block']
# 49679628  :  ['php', 'valu', 'string', 'mysql', 'post', '+', 'binding']
# 50947171  :  ['php', 'file', 'variable', 'empty', 'image', 'upload']
# 48717169  :  ['php', 'array', 'array', 'value']
# 50077269  :  ['php', 'array', 'get', 'database', 'mysql', 'nested']
# 51528865  :  ['php', 'variable', 'class']
# 50697867  :  ['php', 'script', 'database']
# 51995608  :  ['php', 'link', 'css', 'css', 'template', 'due', 'up']
# 50437300  :  ['php', 'html', 'send', 'email', 'attachments']
# 49453735  :  ['php', 'array', 'return', 'soap']
# 50846493  :  ['php', 'json', 'types']
# 49473259  :  ['php', 'field', 'value', '', 'based', 'different', 'attachments', 'attachments']
# 49113917  :  ['php', 'xml', 'soap']
# 48854633  :  ['php', 'if', 'sign', 'switch']
# 50895376  :  ['php', 'array', 'data', 'codeigniter', 'extract']
# 50563471  :  ['php', 'get', 'c#', 'cannot', 'working', 'info']
# 48073172  :  ['php', 'regex']
# 49065739  :  ['php', 'file', 'new', 'folder']
# 49024163  :  ['php', 'data', 'file', 'write', 'memory']
# 51976944  :  ['php', 'connect', 'server', 'sql']
# 50308428  :  ['php', 'numbers', 'sum', 'calculating']
# 48490027  :  ['array', 'values', 'into', 'firebas', 'store', 'multiple', 'loops', 'swift']
# 50375506  :  ['array', 'get', 'id', 'row']
# 49251245  :  ['array', 'index', 'valu', 'pass']
# 50046478  :  ['array', 'unexpected', 'erro', 'json', 'expected', 'close', 'parse']
# 51213914  :  ['array', 'elements', 'aws', 'if', 'bash', 'days']
# 49034436  :  ['array', 'file', 'line', 'into', 'multi']
# 48774083  :  ['data', 'add', 'new', 'index', 'numbers', 'while', 'indices']
# 49246830  :  ['data', 'record', 'update', 'appears', 'if']
# 49085038  :  ['data', 'delete', 'key', 'firebase']
# 51861156  :  ['data', 'into', 'timestamp', 'properly', 'same', 'write', 'order']
# 51022256  :  ['data', 'programmatically', 'detect', 'series', 'fit', 'different', 'pytho']
# 48863538  :  ['data', 'dynamic', 'load', 'js', 'tab']
# 48252278  :  ['data', 'template', 'write', 'custom', 'django', 'rest']
# 51363111  :  ['data']
# 49845854  :  ['data', 'access']
# 49259400  :  ['data', 'page', 'refresh', 'add', 'javascrip', 'js', 'without', 'dynamically']
# 51438840  :  ['data', 'angular', 'into', 'error', 'object']
# 48862559  :  ['data', 'get', 'button', 'angularjs', 'attribute']
# 50738969  :  ['data', 'get', 'unable', 'activity', 'activity']
# 49233328  :  ['data', 'object', 'sql', 'oracle', 'statement', 'extract', 'tables']
# 50078889  :  ['data', 'google', 'add', 'api', 'json', 'map', 'center']
# 51177894  :  ['data', 'get', 'pytho']
# 48524669  :  ['data', 'same', 'firebase', 'different', 'tables']
# 50515913  :  ['data', 'sqlite', 'return']
# 50045119  :  ['data', 'cannot', 'extract', 'days']
# 50284398  :  ['data']
# 50812775  :  ['data', 'snapshot', 'custom', 'show', 'zero']
# 49831478  :  ['data', 'variable', 'into', 'while', 'has', 'exception', 'been', 'loading', 'xml']
# 49248825  :  ['data', 'update', 'pass', 'component', 'component', 'component', 'form', 'info', 'first', 'so', 'edit']
# 50429954  :  ['data', 'method', 'android', 'class', 'call', 'fragment']
# 49459671  :  ['data', 'data', 'within', 'table', 'nested', 'show', 'item']
# 50062178  :  ['data', 'file', 'erro', 'partition', 'missing']
# 50876161  :  ['data', 'error', 'google', 'sheets', 'swift', 'loading', 'loading']
# 51781707  :  ['data', 'after', 'left', 'event', 'has', 'view', 'ionic']
# 51792132  :  ['data', 'swift', 'cell', 'call', 'first', 'first']
# 49514859  :  ['data', 'get', 'android', 'event', 'object']
# 51833930  :  ['data', 'characters', 'remove', 'frame', 'space']
# 49105153  :  ['data', 'data', 'file', 'page', 'fil', 'csv', 'csv', 'asp.net', 'show', 'upload', 'parse', 'up']
# 49548549  :  ['data', 'between']
# 48076491  :  ['data', 'while', 'tab']
# 48532002  :  ['data', 'through', 'access']
# 51342812  :  ['data', 'store']
# 50336850  :  ['data', 'database', 'multiple']
# 48789078  :  ['make', 'virtual', 'video', 'video', 'file', 'i']
# 50270428  :  ['make', 'line', 'button', 'multi']
# 51806839  :  ['make', 'java', 'internal', 'internal', 'frame', 'frame']
# 51292346  :  ['make', 'mysql', 'unable', 'unable', 'connection', 'run']
# 49877097  :  ['make', 'which', 'html', 'want', 'like']
# 48194656  :  ['make', 'html', 'between', 'space']
# 49387336  :  ['make', 'view', 'custom', 'animation']
# 51524632  :  ['make', 'row', 'same', 'if', 'bootstrap', 'first', 'than']
# 50767578  :  ['virtual', 'aws', 'backup']
# 51315972  :  ['video', 'share']
# 48569738  :  ['video', 'swift', 'screen', 'os']
# 50262622  :  ['file', 'into', 'code', 'text']
# 50474923  :  ['file', 'spring', 'excel']
# 49738835  :  ['file', 'script', 'build', 'jenkins']
# 49833987  :  ['file', 'each', 'within', 'same', 'read', 'content', 'fil']
# 48744330  :  ['file', 'browser', 'render', 'pdf']
# 49694460  :  ['file', 'copy', 'directory', 'directory', 'directory', 'current']
# 48261710  :  ['file', 'if', 'check', 'c++']
# 51726990  :  ['file', 'cannot']
# 48421777  :  ['file', 'access', 'camera', 'even']
# 49170779  :  ['file', 'browser', 'error', 'folder', 'via', 'internal']
# 49214880  :  ['file', 'pages', 'upload']
# 50257769  :  ['file', 'class', 'fil', 'bad', 'source']
# 48570977  :  ['file', 'load', 'unable']
# 49440748  :  ['file']
# 50679184  :  ['file', 'method', 'running', 'c#', 'app', 'write', 'service', 'web', 'xml', 'console']
# 50238273  :  ['file', 'only', 'new', 'copy', 'if', 'version']
# 50558610  :  ['file', 'add', 'new', 'child', 'xml', 'report', 'nodes']
# 48584971  :  ['file', 'api', 'convert']
# 51847688  :  ['file', 'c#', 'through', 'windows', 'upload']
# 51699574  :  ['file', 'folde', 'no']
# 49130292  :  ['file', 'main', 'passing', 'process']
# 51437277  :  ['file', 'c#', 'null', 'json', 'returns']
# 52021778  :  ['file', 'error', 'android', 'this', 'loading', 'item']
# 49342267  :  ['file', 'application', 'files', 'types']
# 49359186  :  ['file', 'text', 'list']
# 49891046  :  ['file', 'within', 'xml', 'extracting']
# 51478207  :  ['file', 'js', 'external']
# 51060207  :  ['file', 'javascript']
# 50383163  :  ['file', 'each', 'user', 'search', 'fil', 'instances', 'number']
# 51641854  :  ['file', 'error', 'system', 'directory', 'no']
# 51523013  :  ['file', 'aws', '+']
# 49986295  :  ['file', 'server', 'sql']
# 49847299  :  ['file', 'chrome']
# 51216719  :  ['file', 'empty', 'if', 'implement']
# 51230768  :  ['file', 'html', 'aws', 'read', 'content', 's3']
# 48896480  :  ['file', 'excel', 'microsoft', 'apache', 'poi']
# 49052709  :  ['i', 'mean']
# 51515930  :  ['i', 'open', 'sometimes', 'sometimes']
# 52003787  :  ['i', 'line', 'branch', 'simple']
# 50507561  :  ['i', 'unexpected', 'error', 'message', 'erro', 'r']
# 48392370  :  ['docker', 'variable']
# 50835142  :  ['docker', 'between']
# 51923592  :  ['docker', 'images', 'share']
# 49555011  :  ['docker']
# 48792486  :  ['docker', 'aws', 'left', 'no', 'device', 'space']
# 50208375  :  ['docker', 'docker', 'image', 'image', 'if', 'was', 'change']
# 51554598  :  ['variable', 'valu', 'string', 'convert']
# 49303160  :  ['variable', 'output', 'random', 'creating', 'out']
# 52071882  :  ['variable', 'line', 'pass', 'fil', 'command']
# 49487757  :  ['variable', 'same', 'names']
# 49152905  :  ['variable', 'create', 'bot']
# 50482104  :  ['variable', 'angular', 'multiple', 'template', 'reference']
# 51671457  :  ['variable', 'parent', 'send', 'controller', 'without', 'scope']
# 49638524  :  ['variable', 'insert', 'value', 'system']
# 48066574  :  ['variable', 'vba', 'chart', 'range', 'setting']
# 48941488  :  ['variable', 'variable', 'loop', 'loop', 'within', 'r', 'names']
# 51921897  :  ['variable', 'loop', 'loop', 'javascript', 'outside']
# 51603798  :  ['get', 'network']
# 51398097  :  ['get', 'task', 'date']
# 49768451  :  ['get', 'angular', 'object']
# 51227365  :  ['get']
# 48528637  :  ['get', 'selected', 'c#', 'control', 'property', 'listbox']
# 50941429  :  ['get', 'multiple', 'request', 'info']
# 51260898  :  ['get', 'message', 'event', 'event']
# 50236900  :  ['get', 'java', 'run', 'gradle', 'tests']
# 50806556  :  ['get', 'page', 'value', 'jquery', 'order', 'input', 'view', 'switch']
# 51897471  :  ['get']
# 50146937  :  ['get', 'values', 'every']
# 50511713  :  ['get', 'list', 'map']
# 50408149  :  ['get', 'user', 'input', 'javafx']
# 50417227  :  ['get', '', 'format', 'pytho', 'certain']
# 50754919  :  ['get', 'request', 'https']
# 51189715  :  ['get', 'local', 'id', 'json', 'http']
# 51129851  :  ['get', 'correct', 'position']
# 50027724  :  ['get', 'spring', 'test']
# 51677472  :  ['get', 'link', 'user', 'api']
# 48530322  :  ['get', 'line', 'property']
# 52041481  :  ['get', 'value', 'changes', 'row', 'mysql', 'column', 'query', 'last', 'first', 'before']
# 50484609  :  ['get', 'empty', 'everything', 'between', 'nodes']
# 48423761  :  ['get', 'window']
# 50179535  :  ['local', 'database', 'store', 'information']
# 48862177  :  ['local', 'script', 'jenkins', 'powershell', 'server', 'different', 'sql', 'windows', 'authentication', 'than']
# 51064025  :  ['local', 'method']
# 50458685  :  ['local', 'local', 'date', 'object']
# 51276114  :  ['selected', 'react', 'different', 'dropdown', 'changing', 'route']
# 50152473  :  ['folde', 'after', 'while', '', '', 'code', 'files', 'excel', 'open', 'everything', 'filename']
# 51647140  :  ['folde', 'project', 'any', 'outside', 'cmd']
# 50971893  :  ['folde', 'finding', 'dll', 'dll']
# 50051735  :  ['browser', 'after', 'refresh', 'angular', 'application', 'each', 'deployment']
# 51298931  :  ['browser', 'request', 'bad', 'this', 'server']
# 50658949  :  ['browser', 'script', 'jenkins', 'pass', 'detect', 'then']
# 51097756  :  ['browser', 'after', 'running', 'code', 'current', 'want', 'asp.net', 'tab', 'close']
# 50915207  :  ['browser', 'unexpected', 'selenium']
# 52071015  :  ['reading']
# 48688951  :  ['reading', 'multiple']
# 50620344  :  ['display', 'characters', 'font']
# 49178598  :  ['display', 'image', 'javascrip']
# 51919750  :  ['display', 'jquery', 'working']
# 48683452  :  ['display', 'maps']
# 49785061  :  ['display']
# 48951408  :  ['display', 'add', 'results']
# 48333929  :  ['display', 'xml', 'xml']
# 48549632  :  ['display']
# 50126828  :  ['characters', 'error', 'has']
# 51667953  :  ['characters', 'code', 'replace', 'lines', 'number']
# 48748510  :  ['characters', 'lines', 'before']
# 50058431  :  ['characters', 'create', 'based', 'r', 'column', 'column']
# 48971294  :  ['font', 'way', 'used']
# 49738812  :  ['font', 'setting', 'size']
# 51957441  :  ['font', 'react', 'showing', 'native', 'custom']
# 49110865  :  ['which', 'tensorflow', 'method', 'right']
# 48122726  :  ['which', 'element', 'check', 'was', 'clicked']
# 51936396  :  ['which', 'single', 'inside', 'statement', 'statement', 'if-else', 'if-else']
# 51188430  :  ['which', 'into', 'main', 'json', 'layout']
# 49724312  :  ['which', 'functions']
# 50214003  :  ['which', 'implement', 'recyclerview']
# 50270283  :  ['which', 'output']
# 51749398  :  ['which', 'rows', 'r', 'delete', 'more', 'than', 'x']
# 51200954  :  ['which', 'each', 'bash']
# 49288664  :  ['which', 'mongodb', 'objects', 'range', 'query', 'fit', 'certain', 'coordinates']
# 51597794  :  ['tensorflow', 'error', 'found']
# 48669621  :  ['tensorflow', 'net', 'giving']
# 49752192  :  ['tensorflow', 'error', 'while']
# 51039255  :  ['method', 'calling', 'any']
# 51916433  :  ['method', 'c#', 'duplicate', 'expression']
# 49910362  :  ['method', 'calling', 'fragment']
# 50579998  :  ['method', 'into', 'static', 'bad', 'passing', 'activity', 'fragment']
# 49764941  :  ['method', 'new', 'web']
# 50982401  :  ['method', 'error', 'cannot', 'object', 'gives', 'ajax', 'cast']
# 48100010  :  ['right', 'android', 'canvas', 'around']
# 48926542  :  ['right', 'move', 'scroll', 'left']
# 51948496  :  ['field', 'columns', 'auto', 'value']
# 50177364  :  ['field', 'text', 'expected']
# 48222632  :  ['field', 'text', 'replace', 'pdf', 'form', 'form']
# 50038922  :  ['field', 'vba', 'working', 'results', 'expected', 'document']
# 51365627  :  ['field', 'value', 'change']
# 52069031  :  ['field']
# 49311617  :  ['field', 'only', 'value', 'fail', 'validation', 'has']
# 50777430  :  ['elements', 'move', 'properly', 'length', 'ui', 'unit']
# 50580784  :  ['elements', 'spring', 'request', 'controller', 'rest']
# 48223396  :  ['elements', 'angular', '', 'user', 'if', 'working', 'hiding']
# 50792050  :  ['elements', 'line', 'set', 'bootstrap']
# 50210753  :  ['elements', 'access', 'memory']
# 50666793  :  ['elements', 'list', 'string', 'remove']
# 50380588  :  ['elements', 'multiple', 'length', 'same', 'print', 'different', 'different', 'out', 'compare']
# 51266616  :  ['elements', 'check', 'no', 'see', 'desired']
# 49085533  :  ['elements', 'multiple', 'different']
# 48355631  :  ['html', 'files', 'laravel', 'include', 'template']
# 50708295  :  ['html', 'specific', 'select', 'child']
# 50377940  :  ['html', 'button', 'form', 'center']
# 48708291  :  ['html', 'convert', 'selection']
# 51868089  :  ['html', 'each', 'continuation']
# 50032266  :  ['html', 'code', 'replace', 'java']
# 51665154  :  ['html', 'specific', 'open', 'possible']
# 50618171  :  ['after', 'update', 'full', 'chart']
# 50408049  :  ['after']
# 49442520  :  ['after', 'value', 'value', 'element', 'list', 'same', 'any', 'select', 'dropdown', 'then', 'return', 'selection', 'lis']
# 50127402  :  ['after', 'running', 'has', 'pyqt', 'window', 'been']
# 50169469  :  ['after', 'error', 'message', 'javascript']
# 51139629  :  ['after', 'deployment', 'node.js', 'app', 'heroku', 'errors', 'boot']
# 51415740  :  ['after', 'line', 'line', 'unexpected', 'level', 'at', 'continuation', 'continuation', 'character', 'character']
# 50591997  :  ['after', 'app', 'service']
# 49147569  :  ['after']
# 48843008  :  ['after', 'fail', 'connect']
# 49803513  :  ['after', '', 'request', 'session', 'symfony', 'ajax']
# 49308320  :  ['after', 'user', 'failed', 'login', 'x']
# 50125206  :  ['after', 'text', 'menu', 'unable', 'context', 'select']
# 50227742  :  ['after', '', 'list', 'mysql', 'query', 'missing', 'argument']
# 51761704  :  ['page', 'load', 'working', 'asp.net', 'mvc']
# 50995600  :  ['page', 'error']
# 49431670  :  ['page', 'content']
# 51225991  :  ['page']
# 48516559  :  ['page', 'page', 'loading', 'process']
# 48298937  :  ['page', 'bottom']
# 49032167  :  ['page', 'refresh', 'angular', 'button', 'user', 'want', 'route']
# 51314052  :  ['page', '', 'adding']
# 51605206  :  ['values', 'fetch', 'nested']
# 51846310  :  ['values', 'value', 'column', 'group', 'filter']
# 50092992  :  ['values', 'loop', 'full', 'if', 'check']
# 51591560  :  ['values', 'erro', 'erro', 'up']
# 51235590  :  ['values', 'into', 'loop', 'multiple', 'block', 'block', 'different', 'variables']
# 51788184  :  ['values', 'single', 'actions', 'lazy', 'node']
# 49552144  :  ['values', 'next', 'table', 'output', 'query', 'query', 'select']
# 50573592  :  ['values', 'indices', 'pandas', 'finding']
# 48159489  :  ['log']
# 48676143  :  ['log', 'timestamp', 'timestamp', 'elasticsearch']
# 51720097  :  ['log', 'log', 'calculate', 'like', 'functions']
# 50468204  :  ['log']
# 50992546  :  ['log', 'script', 'working', 'client', 'execution']
# 50494831  :  ['log', 'full', 'server', 'sql', 'than', 'backup', 'backup']
# 48812747  :  ['aws']
# 49749227  :  ['aws', 'access', 'control', 's3']
# 50324639  :  ['aws', 'only', 'force', 'possible', 'https']
# 50836214  :  ['only', 'single', 'running']
# 49089937  :  ['only', 'match', 'need', 'need', 'search', 'string']
# 49806115  :  ['only', 'header', 'new', 'c#', 'plugin', 'messages']
# 50713238  :  ['only', 'build']
# 50635568  :  ['only', 'files', 'filename', 'folder', 'compare']
# 48448477  :  ['only', 'found', 'object', 'symfony']
# 51362316  :  ['only', 'extension', 'out', 'out', 'chrome']
# 51587810  :  ['only', 'columns', 'duplicate', 'column', 'fetch', 'remove', 'names']
# 50465564  :  ['only', 'button', 'tab']
# 48813968  :  ['only', 'columns', 'machine']
# 48108635  :  ['single', 'create', 'task', 'test']
# 48812482  :  ['running', 'application', 'java', 'service', 'show']
# 51694525  :  ['running', 'script', 'code', 'java', 'js']
# 48507363  :  ['running', 'application', 'c#', 'windows', 'keep', 'service', 'stop', 'cmd']
# 50475078  :  ['running', 'js', 'query', 'node']
# 49226228  :  ['running', 'every']
# 49335748  :  ['running', 'spring', 'exception', 'boot', 'cmd']
# 50097539  :  ['angular']
# 50478988  :  ['angular', 'create', 'ui']
# 51606963  :  ['angular', '', 'select', 'dropdown', 'set']
# 50414225  :  ['angular', 'working', 'lazy']
# 50589676  :  ['angular', 'd3']
# 51326496  :  ['angular', 'into', 'string', 'input', 'binding', 'result']
# 48558892  :  ['angular', 'test', 'unit']
# 50172055  :  ['angular', '', '', 'detect']
# 48172271  :  ['angular', 'unit', 'disable', 'console']
# 52091614  :  ['angular', 'error', 'gives', 'me', 'console']
# 51283738  :  ['angular', 'error', 'erro', 'js']
# 50086228  :  ['angular', 'component', 'component', 'property']
# 48645555  :  ['angular', 'event']
# 51308053  :  ['application', 'working', 'without']
# 48667995  :  ['application']
# 49616344  :  ['application', 'model', 'nested', 'form', 'rails']
# 49351604  :  ['application', 'spring', 'heroku', 'boot', 'boot']
# 49788958  :  ['application', 'azure']
# 51740315  :  ['application', 'java', 'memory', 'out']
# 51497670  :  ['application', 'add', 'macos', 'console']
# 51190315  :  ['application', 'implement', 'post']
# 48223472  :  ['application', 'database']
# 51375124  :  ['each', 'columns', 'value', 'calculating', 'based', 'valu', 'element']
# 48615089  :  ['each', 'dat', 'different', 'chrome', 'windows', '+']
# 52038075  :  ['each', 'calculate', 'excel', 'cell', 'variables', 'reference']
# 49572464  :  ['each', 'columns', 'css', 'grid', 'row', 'different', 'layout', 'number']
# 51683506  :  ['each', 'time', 'series']
# 50312634  :  ['deployment', 'erro', 'you', 'app', 'app', 'include', 'invalid', 'ios', 'so']
# 49073052  :  ['network', 'javascript']
# 51763689  :  ['network', 'hyperledger']
# 50163645  :  ['network', 'error', 'mongodb', 'connection', 'azure']
# 51262915  :  ['network', 'loops', 'random']
# 49625967  :  ['insert', 'some', 'line', 'script', 'script', 'into', 'main']
# 50776764  :  ['insert', 'chart', 'hover', 'd3', 'd3']
# 48426285  :  ['insert']
# 51589605  :  ['insert', 'into', 'working', 'oracle']
# 49399411  :  ['insert', 'jquery', 'without', 'without', 'div']
# 51036495  :  ['insert', 'loop', 'mysql', 'expected', 'nodejs']
# 51096704  :  ['some', 'delete', 'django', 'errors']
# 52004057  :  ['some', 'dropdown', 'disable']
# 51064493  :  ['some', 'specific', 'block', 'http']
# 50818351  :  ['some', 'google', 'app', 'working']
# 48759521  :  ['line', 'replace', 'regex']
# 48588468  :  ['line', 'add', 'text', 'grid', 'ui', 'multi']
# 49990180  :  ['line', 'multiple', 'same', 'output']
# 49128874  :  ['line', 'command', 'more', 'than']
# 49558881  :  ['line', 'line', 'new']
# 49769595  :  ['script', 'npm']
# 51977844  :  ['script', 'google', 'chart', 'app', 'copy', 'static']
# 49379903  :  ['script', 'output', 'query', 'shell', 'sql']
# 50326377  :  ['script', 'api', 'asp.net', 'shell', 'web', 'possible']
# 49156845  :  ['script', 'character', 'os', 'x']
# 50294139  :  ['into', 'merge', 'original']
# 51536806  :  ['into', 'excel', 'change']
# 50165068  :  ['into', 'parent', 'move', 'property', 'child']
# 49729227  :  ['into', 'pdf', 'document']
# 48149850  :  ['into', 'google', 'image', 'javascript', 'convert', 'map', 'route']
# 48869529  :  ['into']
# 50897717  :  ['into', 'error', 'entity', 'already', 'gives', 'collections', 'collections']
# 51307690  :  ['into', 'code', 'java']
# 50312018  :  ['columns', 'mean', 'taking', 'merge', 'pandas', 'between']
# 51039663  :  ['columns', 'multiple', 'query', 'sql', 'calling']
# 51113076  :  ['columns', 'rows']
# 51831568  :  ['columns', 'range', 'column']
# 50751210  :  ['auto', 'no', 'role']
# 50682018  :  ['auto', 'non', 'simple', 'see']
# 48973117  :  ['auto', 'error', 'create', 'django']
# 50379971  :  ['value', 'add', 'specific', 'row', 'range']
# 49054252  :  ['value', 'adding']
# 49435143  :  ['value', 'access', 'microsoft', 'form', 'listbox']
# 48363497  :  ['value', 'grid', 'missing']
# 48302009  :  ['value', 'print', 'shape']
# 51137757  :  ['value', 'multiple']
# 52023089  :  ['value', 'changes', 'until', 'swift']
# 50716542  :  ['value', 'show']
# 52077503  :  ['value', 'add', '', 'sign', 'input', 'before']
# 51078271  :  ['value', 'javascript', 'keep', 'character']
# 48996409  :  ['value', 'based', 'multiple', 'row', 'column']
# 51716503  :  ['value', '', 'range', 'out']
# 50251991  :  ['value', 'returns']
# 50841739  :  ['value', 'pass']
# 51830335  :  ['unexpected', 'token', 'import']
# 49339509  :  ['unexpected', 'error', '', 'date', 'range']
# 48404042  :  ['token', '', 'firebas', 'create', 'dynamic', 'link', 'user', 'id']
# 51589076  :  ['token', 'access', 'functions', 'cloud', 'expected']
# 48252891  :  ['import', 'unable']
# 50767910  :  ['header', 'creation']
# 48571421  :  ['creation', '', '', 'invalid', 'memory', 'take', 'snapshot', 'snapshot', 'fails']
# 51723310  :  ['empty', 'error', 'message']
# 48153613  :  ['empty', 'way', 'keep']
# 50597457  :  ['empty', '', '', 'android', 'class', 'test', 'test', 'found', 'name', 'unit', 'package']
# 50319567  :  ['error', 'project', 'simple', 'connect', 'mysql', 'node.js']
# 51143902  :  ['error', 'compiling']
# 48050305  :  ['error', '', 'symfony', 'invalid']
# 48913778  :  ['error', 'c#', 'send', 'http', 'async']
# 52064590  :  ['error', 'add']
# 51015830  :  ['error', 'request', 'xml', 'soap']
# 49065471  :  ['error', 'request', 'bad', 'angularjs']
# 51814879  :  ['error']
# 50972613  :  ['error']
# 50165589  :  ['error', 'react', 'level', 'native']
# 52020956  :  ['error', 'dat', 'found', 'object']
# 48583017  :  ['error']
# 51878631  :  ['error', 'while', 'c++', 'c++', 'map']
# 50162942  :  ['error', 'validation']
# 51579806  :  ['error', 'duplicate', 'library', 'external']
# 50105933  :  ['error']
# 48702955  :  ['error', 'changing']
# 51369689  :  ['error', 'code', 'excel', 'source']
# 50079207  :  ['error', 'compiling']
# 51644456  :  ['error']
# 49424571  :  ['error', 'build', 'giving']
# 48331115  :  ['error', 'error', 'while', 'calling']
# 51294933  :  ['error', 'message', '', 'no', 'net', 'framework']
# 48423704  :  ['error', 'code', 'process']
# 51292579  :  ['error', 'no', 'https']
# 51380203  :  ['error', 'spring', 'mvc', 'program']
# 49794361  :  ['error', 'error', 'laravel', 'giving']
# 49222046  :  ['message', 'message', 'full', 'java', 'server', 'client']
# 51015380  :  ['message', 'javascript', 'checkbox', 'firing']
# 50307860  :  ['google']
# 51762042  :  ['google', 'laravel', 'working', 'sign']
# 49043508  :  ['google', 'maps', 'view']
# 50653749  :  ['google', 'android', 'maps', 'ionic', 'show', 'map']
# 50476429  :  ['google', 'cannot', 'load', 'connect', 'inside', 'external', 'instances']
# 50335637  :  ['google', 'cloud']
# 51813887  :  ['google', 'sheets', 'date']
# 51310340  :  ['google', 'shell', 'cloud', 'loading', 'resources']
# 52013459  :  ['google', 'full', 'maps', 'div', 'screen', 'show']
# 48848751  :  ['add', 'taking', 'time']
# 48103307  :  ['add', 'form', 'external', 'source']
# 49796161  :  ['add', 'link']
# 49380501  :  ['add', 'order', 'order', 'custom']
# 50860630  :  ['add', 'webview', 'resources']
# 48631118  :  ['add', 'text', 'specific', 'domain']
# 51277171  :  ['add']
# 49118025  :  ['add', 'class', 'jquery', 'include', 'div', 'onclick']
# 51039840  :  ['add', 'api']
# 48577913  :  ['add', 'class', 'same', 'entity', 'framework']
# 51316728  :  ['add']
# 49896966  :  ['add', 'element', 'jquery']
# 51092602  :  ['add', 'table', 'tab', 'pyqt']
# 52023608  :  ['add']
# 48879150  :  ['new', 'string', 'pass', 'c', 'without', 'copying']
# 51293877  :  ['new', 'session', 'entity']
# 50490291  :  ['new', 'access', 'react', 'context', 'api']
# 51413915  :  ['new', 'update', 'authentication']
# 52016207  :  ['new', 'at']
# 50400841  :  ['new']
# 51175133  :  ['new', 'move', 'row', 'server', 'sql']
# 51242700  :  ['index', 'elasticsearch', 'search', 'time', 'result']
# 50619120  :  ['index', 'specific', 'update', 'duplicate', 'at', 'check', 'listbox', 'item']
# 51126316  :  ['index', 'list', 'without', 'way', 'retrieve']
# 48287340  :  ['numbers', 'user', 'java', 'at']
# 50755731  :  ['while', '', 'failed', 'task', 'firebase', 'execution']
# 48252638  :  ['while', 'css', 'css', 'unit']
# 48175792  :  ['while', 'undefined']
# 51066459  :  ['indices', 'multiple', 'elasticsearch']
# 50552046  :  ['button', 'replace', 'react', 'component', 'event', 'js']
# 49016454  :  ['button', 'chart', 'render', 'javafx']
# 49831755  :  ['button', 'javafx', 'animation', 'hover']
# 51675277  :  ['button', 'working', 'open', 'close', 'bootstrap', 'first']
# 50727123  :  ['button', 'chart', 'showing']
# 50305756  :  ['button', 'javascript', 'switch']
# 51049876  :  ['button', 'image', 'effect', 'clicked']
# 48588085  :  ['click', 'javafx', 'change', 'coordinates']
# 50446667  :  ['click', 'event', 'sometimes', 'ionic', 'web', 'ap']
# 51042547  :  ['click', 'remove', 'angularjs']
# 50067652  :  ['click', 'jquery', 'onclick']
# 49347615  :  ['c#', 'access', 'list', 'class']
# 49051827  :  ['c#']
# 49678358  :  ['c#', 'files', 'set', 'version']
# 51890616  :  ['c#', '', 'specific', 'email', 'email', 'via', 'via']
# 50885874  :  ['c#', 'inside', 'property']
# 48904087  :  ['c#', 'create', 'multiple', 'pass', 'same', 'same', 'at', 'time', 'different', 'instances']
# 51115695  :  ['spring', '', 'fail']
# 51578263  :  ['spring']
# 48467222  :  ['spring', 'set', 'character']
# 50319442  :  ['spring', 'mvc', 'pages']
# 49303316  :  ['spring', 'unable', 'server', 'cloud', 'configure']
# 50111039  :  ['spring', 'messages']
# 50043626  :  ['spring', 'boot', 'configure', 'framework']
# 49227957  :  ['spring', 'if', 'take', 'service']
# 50364614  :  ['', 'image', 'control', 'images']
# 49748294  :  ['']
# 48588572  :  ['', 'within', 'js']
# 51434829  :  ['', 'if', 'equal']
# 48111612  :  ['', 'access', 'image', 'r', 'service']
# 52008850  :  ['', 'regex', 'string']
# 52121253  :  ['', 'react', 'load', 'app', 'component', 'inside']
# 50852606  :  ['', 'onclick']
# 51362925  :  ['', 'test', 'current', 'stop']
# 49597125  :  ['', 'block', 'nested']
# 50154427  :  ['']
# 49543526  :  ['', 'android', 'store', 'app', 'null', 'size']
# 51858026  :  ['', 'update', 'react', 'object', 'native', 'call']
# 50686205  :  ['fail', 'selenium', 'tests']
# 51317890  :  ['code', 'c', 'generate']
# 49024783  :  ['code', 'this']
# 49383734  :  ['code', 'copy', 'want', 's3']
# 48732554  :  ['code', 'many', 'update', 'object', 'relationship', 'first']
# 49939088  :  ['text']
# 52090488  :  ['changes', 'replace', 'branch']
# 48892836  :  ['branch', 'exception']
# 49899419  :  ['create', 'test']
# 48680733  :  ['create', 'table', 'r']
# 49772455  :  ['create', 'id', 'erro', 'duplicate', 'same', 'object', 'unable', 'key', 'different', 'due']
# 51757396  :  ['create']
# 50513269  :  ['create', 'custom']
# 51441456  :  ['create', 'list', 'parent', 'jquery', 'different', 'child', 'xml', 'nodes']
# 48309992  :  ['dynamic', 'items', 'event']
# 49001429  :  ['dynamic', 'api', 'client']
# 50059729  :  ['dynamic', 'td', 'show']
# 50987796  :  ['link', 'open']
# 51835539  :  ['user', 'based', 'input', 'core']
# 52041971  :  ['user', 'has', 'has', 'detect', 'been', 'clicked', 'outside', 'close']
# 48501220  :  ['user', 'send']
# 49834807  :  ['user']
# 48474019  :  ['user', 'based', 'if', 'check', 'api', 'role', 'role', 'asp.net', 'custom', 'authentication', 'web', 'attribute']
# 49841777  :  ['user', 'access', 'laravel', 'tables', 'pivot']
# 48794656  :  ['user', 'template', 'authentication', 'group']
# 48316803  :  ['id', 'relationship', 'property']
# 49454900  :  ['id', 'same', 'if', 'share', 'position']
# 51061741  :  ['id', 'vba', 'screen', 'shape', 'finding']
# 48321884  :  ['id', 'model', 'custom']
# 49699935  :  ['match', 'lines', 'specific']
# 50771873  :  ['match', 'way']
# 50058104  :  ['match', 'same', 'different', 'zero']
# 50816798  :  ['match', 'database', 'string']
# 49878732  :  ['specific', 'find', 'folder', 'folder', 'way']
# 48784619  :  ['specific', 'tab', 'information', 'parse', 'poi']
# 49176011  :  ['specific', 'update', 'at']
# 51099364  :  ['specific', 'event', 'javafx']
# 49491501  :  ['specific', 'time', 'time', 'different', 'extracting']
# 50795587  :  ['specific', 'domain', 'server']
# 49810280  :  ['specific', 'record', 'store', 'screen']
# 51065379  :  ['specific', 'instead', 'app', 'open', 'device', 'setting']
# 49351881  :  ['loop', 'through', 'sheets', 'calculate', 'sum', 'vba']
# 49078238  :  ['loop', 'implementing']
# 50595558  :  ['loop', 'scroll', 'selenium']
# 48908228  :  ['loop', 'nodejs']
# 49971183  :  ['loop', 'java', 'if', 'certain']
# 49322961  :  ['loop', 'javascrip', 'objects', 'django']
# 50109915  :  ['loop', 'r', 'first']
# 49386775  :  ['loop', 'inside', 'nodejs']
# 48337248  :  ['through', 'access', 'react', 'camera', 'native', 'webview']
# 48699435  :  ['calculate']
# 49542370  :  ['sum', 'working']
# 51824123  :  ['vba', 'reference']
# 50762909  :  ['vba', 'items', 'table', 'remove', 'filter', 'pivot']
# 49597027  :  ['record']
# 48252826  :  ['record']
# 51455954  :  ['calculating', 'items', 'sql']
# 50851713  :  ['based', 'element']
# 48704882  :  ['valu', 'checkbox', 'group', 'edit', 'changing']
# 48670628  :  ['element']
# 49941301  :  ['element', 'adding', 'div', 'td', 'dynamically']
# 50206671  :  ['element', 'if', 'if', 'jquery', 'check', 'block', 'statement']
# 50164490  :  ['android', 'read', 'camera', 'level']
# 48062436  :  ['android', 'event']
# 50206103  :  ['android', 'device']
# 51716528  :  ['android', 'returns', 'webview']
# 51136502  :  ['android', 'compiling']
# 50060245  :  ['android', 'issue', 'recyclerview', 'layout']
# 51012683  :  ['android', 'react', 'programmatically', 'device', 'via']
# 49157256  :  ['android', 'set']
# 51140905  :  ['android', 'lis', 'exception', 'gives']
# 50054420  :  ['canvas', 'appears']
# 48124530  :  ['canvas', 'java']
# 49011970  :  ['around', 'css', 'object']
# 49873649  :  ['around']
# 50319317  :  ['mean', 'model', 'system']
# 49391012  :  ['sqlite', 'sqlite', 'many', 'database', 'files']
# 50745098  :  ['many', 'loops', 'too']
# 49306419  :  ['many', 'files', 'open', 'too']
# 51477671  :  ['database', 'connect', 'oracle']
# 49822061  :  ['database', 'sql']
# 50338651  :  ['database']
# 49425070  :  ['database', 'image', 'server', 'upload']
# 49286875  :  ['database', 'firebase', 'notifications']
# 50321245  :  ['files', 'issue']
# 51844103  :  ['files', 'source']
# 50685903  :  ['files', 'folder', 'different', 'upload']
# 51198614  :  ['files', 'machine', 'any']
# 49435875  :  ['regex', 'remove']
# 50702875  :  ['regex', 'parent', 'print', 'ios', 'child']
# 48066954  :  ['regex', 'length', 'group', 'so']
# 49010702  :  ['access', 'erro', 'you', 'form']
# 50031437  :  ['access']
# 50455529  :  ['access', 'you', 'if', 'control', 'session', 'chrome', 'possible']
# 49225709  :  ['access', 'react', 'firebase', 'native', 'exception', 'c++']
# 49866795  :  ['access', 'query', 'creating']
# 48228009  :  ['list', 'object', 'write', 'way']
# 49327461  :  ['list', 'update']
# 48463287  :  ['list', 'pass', 'retrieve']
# 51304471  :  ['list', 'edit']
# 49133609  :  ['list', 'pytho']
# 50193162  :  ['class', 'cannot', 'find', 'folder', 'codeigniter']
# 50069060  :  ['class', 'issue', 'scope']
# 49964955  :  ['class', 'exception', 'cast']
# 51925068  :  ['failed', 'until']
# 48421676  :  ['failed', 'task', 'execution']
# 49184516  :  ['failed', 'delete', 'was', 'service']
# 50962899  :  ['failed', 'task', 'unable', 'execution']
# 50064377  :  ['until', 'eclipse', 'console', 'program']
# 50893972  :  ['excel', 'apache', 'tables', 'first', 'poi', 'hiding', 'pivot']
# 51323296  :  ['multiple', 'search', 'api', 'filter']
# 49561118  :  ['multiple']
# 49154422  :  ['multiple', 'order', 'different']
# 51349032  :  ['multiple', 'item']
# 49517118  :  ['multiple']
# 51716380  :  ['multiple', 'mysql']
# 49855443  :  ['multiple', 'if', 'write', 'way']
# 49907961  :  ['swift', 'json', 'nested', 'complex']
# 48447257  :  ['timestamp', 'update', 'cell']
# 50087029  :  ['task']
# 50242282  :  ['date', 'string', 'format', 'api', 'convert', 'post']
# 48622558  :  ['date', 'cannot', 'correct', 'retrieve']
# 49804177  :  ['image', 'unable', 'retrieve']
# 50792800  :  ['image', 'directory', 'upload']
# 48266692  :  ['image']
# 51548792  :  ['image']
# 51498829  :  ['image', 'css', 'original', 'size', 'up']
# 51110845  :  ['javascrip', 'constructor', 'native']
# 50651974  :  ['effect', 'menu']
# 50805412  :  ['effect', 'no']
# 51663147  :  ['menu', 'grid', 'content']
# 48744497  :  ['update', 'sql']
# 51010352  :  ['update']
# 48544246  :  ['update', 'css', 'dynamically']
# 49275321  :  ['update', 'unable', 'hyperledger']
# 48891258  :  ['update', 'test', 'need', 'if']
# 50192001  :  ['chart', 'time']
# 50928170  :  ['mongodb', 'parent']
# 51433586  :  ['parent', 'render', 'component', 'children', 'them']
# 49461594  :  ['parent', 'then', 'children', 'group']
# 50241802  :  ['build']
# 51625240  :  ['build', 'static', 'if']
# 48480284  :  ['erro', 'this']
# 49429114  :  ['cannot', 'read', 'property', 'already', 'post', 'typeerro', 'action', 'undefined']
# 49195036  :  ['cannot', 'table', 'disable']
# 48386660  :  ['cannot', 'constructor']
# 50764572  :  ['dat', 'model', 'model', 'test', 'test', 'same', 'original']
# 50525208  :  ['npm', 'node']
# 49566318  :  ['npm', 'change']
# 50860095  :  ['java', 'plugin', 'plugin', 'custom', 'gradle', 'gradle', 'configure']
# 51934060  :  ['java', 'string', 'json', 'expression']
# 51504397  :  ['java', 'time', 'between']
# 48101490  :  ['java', 'already', 'install']
# 48792070  :  ['project', 'eclipse', 'library', 'missing']
# 51963775  :  ['eclipse', 'include']
# 50793381  :  ['eclipse']
# 48141348  :  ['model', 'test', 'if', 'rails']
# 50062258  :  ['model', 'send', 'controller', 'dynamically', 'mvc', 'dll']
# 49211248  :  ['system']
# 49201157  :  ['test', 'name', 'name', 'fil', 'column', 'csv']
# 49711137  :  ['test', 'programmatically', 'ios', 'device', 'version']
# 51736580  :  ['instead']
# 49902294  :  ['instead', 'laravel', 'print']
# 50374972  :  ['implementing', 'extension']
# 49213073  :  ['implementing', 'app']
# 50336084  :  ['extension', 'install']
# 49882260  :  ['found', 'connect']
# 50645467  :  ['found', 'oracle']
# 50881835  :  ['found', 'working', 'post']
# 51708379  :  ['react', 'load', 'rows']
# 49958178  :  ['react', 'any', 'children']
# 49348227  :  ['react', 'view', 'native']
# 49711120  :  ['react', 'native', 'close', 'even']
# 50260837  :  ['load', 'at', 'template']
# 51716083  :  ['rows', 'table', 'template', 'generate']
# 49903971  :  ['rows', 'find']
# 51385574  :  ['rows', 'report', 'hiding']
# 50239549  :  ['move']
# 49341610  :  ['scroll', 'programmatically']
# 50542765  :  ['left', 'screen', 'like', 'up']
# 49879320  :  ['left']
# 50613827  :  ['css', 'grid', 'grid', 'row', 'row', 'next']
# 49530905  :  ['grid', 'set']
# 48471737  :  ['next', 'if']
# 49313367  :  ['non']
# 51586581  :  ['non', 'r']
# 48612637  :  ['items', 'implement', 'django']
# 49345003  :  ['objects', 'native']
# 50588453  :  ['string', 'javascript', 'fetch', 'query']
# 50183471  :  ['string']
# 50633524  :  ['string', 'argument']
# 49913313  :  ['string', 'xml', 'parse']
# 50159805  :  ['string', 'column', 'force', 'datetime']
# 50611493  :  ['send', 'powershell']
# 50047951  :  ['powershell', 'open']
# 49571917  :  ['laravel']
# 48790762  :  ['laravel', 'app', 'issue']
# 51401194  :  ['request', 'api', 'call', 'soap']
# 49692598  :  ['request', 'nodejs']
# 52112273  :  ['validation', 'jquery', 'generate', 'errors']
# 49314277  :  ['email', 'domain', 'name', 'javascript']
# 50701812  :  ['javascript', 'custom', 'firing']
# 49659641  :  ['within', 'machine']
# 51758944  :  ['within', 'report', 'every']
# 49707785  :  ['properly', 'working', 'angularjs']
# 51746282  :  ['properly', 'bootstrap']
# 51173729  :  ['you', 'reverse', 'bottom']
# 49576502  :  ['you', 'convert', 'between', 'zero', 'coordinates', 'coordinates']
# 49703224  :  ['bottom', 'if', 'jquery', 'check', 'has', 'hit']
# 48890542  :  ['connect', 'mysql']
# 50049645  :  ['mysql', 'column', 'column', 'convert', 'datetime']
# 49213499  :  ['node.js']
# 51910079  :  ['app', 'event', 'adding']
# 48153044  :  ['app', 'firebase', 'version', 'being']
# 48945332  :  ['same', 'codeigniter', 'different', 'different', 'form', 'show', 'pages', 'result', 'ajax']
# 49714999  :  ['same', 'output', 'them']
# 48409295  :  ['read', 'exception']
# 48266729  :  ['content', 'force']
# 50299640  :  ['fil', 'current', 'change', 'layout']
# 50108147  :  ['render', 'object', 'without', 'possible', 'cast']
# 50875280  :  ['component', 'apache', 'apache', 'hit']
# 49796868  :  ['component']
# 48209823  :  ['event', 'firing']
# 48369085  :  ['event', 'jquery', 'input', 'change']
# 50115532  :  ['js', 'different', 'node']
# 48086394  :  ['appears', 'ios', 'set', 'outside']
# 49346242  :  ['if', 'check', 'command', 'has', 'output']
# 48355335  :  ['if', 'check']
# 48692956  :  ['if', 'change']
# 51435945  :  ['if', 'output', 'output', 'output', 'equal', 'see', 'compare', 'than']
# 49982792  :  ['if', 'if']
# 50271376  :  ['if', 'post', 'variables']
# 51152931  :  ['object', 'typeerro', 'undefined']
# 49684935  :  ['object', 'object', 'pyqt']
# 48558372  :  ['object', 'has', 'no', 'lis', 'attribute']
# 48196653  :  ['object', 'null']
# 49795453  :  ['jquery', 'null', 'time', 'datetime']
# 51419069  :  ['jquery', 'animation']
# 49459920  :  ['working']
# 48948859  :  ['working', 'attribute']
# 50269510  :  ['working', 'async']
# 50346370  :  ['working', 'pytho']
# 51190619  :  ['working', 'query', 'sql', 'desired']
# 50989420  :  ['r']
# 51162398  :  ['r']
# 51823015  :  ['print']
# 49056718  :  ['print', 'remove', 'statement', 'certain']
# 49512891  :  ['null', 'controller']
# 51972638  :  ['controller', 'service']
# 51797384  :  ['images']
# 49718732  :  ['images']
# 48438957  :  ['level']
# 48191023  :  ['unable', 'library']
# 48618325  :  ['unable', 'functions', 'heroku']
# 49535533  :  ['unable']
# 50645254  :  ['library', 'issue', 'net']
# 49017213  :  ['library']
# 49192540  :  ['library']
# 49798316  :  ['at', 'fails']
# 51743310  :  ['open', 'has', 'different', 'them']
# 51010372  :  ['current']
# 50253772  :  ['everything', 'time', 'loading']
# 49027944  :  ['filename']
# 49522558  :  ['key', 'query', 'want', 'partition']
# 48864742  :  ['c', 'pointer']
# 48608946  :  ['c']
# 49743441  :  ['without', 'relationship']
# 49844264  :  ['without', 'different', 'equal']
# 51468573  :  ['without', 'via']
# 49323144  :  ['session', 'symfony', 'time']
# 52091351  :  ['entity']
# 48932795  :  ['check', 'inside', 'api']
# 48192089  :  ['has', 'no', 'attribute', 'module']
# 48940740  :  ['server', 'query', 'sql']
# 51107427  :  ['correct']
# 49542303  :  ['issue']
# 48788784  :  ['issue', 'plugin', 'native', 'ionic']
# 51413613  :  ['issue']
# 50410939  :  ['find', 'number', 'document']
# 49905550  :  ['find', 'models']
# 48245327  :  ['column', 'sql', 'selection']
# 52068979  :  ['column', 'adding', 'dynamically', 'binding', 'collections']
# 49767093  :  ['csv', 'rails', 'errors', 'returns']
# 51784232  :  ['format', 'convert']
# 48795036  :  ['actions', 'microsoft']
# 50905888  :  ['actions']
# 48070082  :  ['context', 'between', 'passing']
# 51888876  :  ['query', 'sql', 'expected', 'giving', 'result']
# 51881725  :  ['want', 'any', 'notifications', 'notifications', 'like']
# 52121019  :  ['plugin']
# 50818495  :  ['messages']
# 49574377  :  ['messages', 'azure']
# 49185020  :  ['template', 'call', 'used']
# 48554485  :  ['template', 'inheritance']
# 51318698  :  ['json']
# 49564256  :  ['order']
# 48208911  :  ['implement']
# 49773547  :  ['implement', 'hyperledger']
# 50752929  :  ['implement']
# 48681430  :  ['generate']
# 49360786  :  ['input', 'input']
# 51849347  :  ['input', 'shape']
# 51997245  :  ['time']
# 50444707  :  ['memory', 'out']
# 48880257  :  ['take', 'form', 'names']
# 50833520  :  ['fails', 'run']
# 48315286  :  ['td', 'td', 'change', 'hover']
# 49775177  :  ['merge', 'models']
# 50550449  :  ['showing']
# 50114632  :  ['detect']
# 48876570  :  ['series']
# 51321905  :  ['fit', '+']
# 48768927  :  ['different']
# 49074417  :  ['asp.net', 'core']
# 50003219  :  ['sql', 'group', 'days']
# 48943721  :  ['oracle', 'too']
# 50961736  :  ['statement', 'form', 'bootstrap', 'due', 'if-else']
# 51078621  :  ['creating', 'out', 'pandas']
# 48142935  :  ['creating']
# 48277673  :  ['convert', 'scala']
# 49540314  :  ['action']
# 51657680  :  ['windows', 'too', 'os']
# 50763202  :  ['+']
# 50875966  :  ['+', 'problems']
# 51309214  :  ['functions', 'azure']
# 49223515  :  ['constructor', 'being']
# 51255994  :  ['nested', 'recyclerview']
# 52074528  :  ['nested']
# 49086074  :  ['package']
# 48940120  :  ['expected', 'than']
# 48292332  :  ['expected', 'django', 'exception']
# 48378206  :  ['expression', 'extracting']
# 50335886  :  ['custom', 'set']
# 52004910  :  ['django', 'information', 'console']
# 50673806  :  ['django', 'rest', 'framework']
# 50679025  :  ['disable']
# 50098276  :  ['login', 'was', 'authentication', 'see']
# 50942270  :  ['login', 'external', 'gives', 'http']
# 49413282  :  ['used', 'than']
# 51684094  :  ['ionic']
# 49319165  :  ['core', 'net', 'ap']
# 51857883  :  ['client']
# 49997746  :  ['window']
# 51938926  :  ['inheritance', 'complex']
# 49411073  :  ['show']
# 51244309  :  ['show']
# 51504466  :  ['lazy', 'loading', 'connection']
# 48853788  :  ['connection', 'configure']
# 49761320  :  ['recyclerview']
# 52084523  :  ['retrieve', 'document']
# 49908633  :  ['net']
# 51134124  :  ['map', 'between']
# 50071207  :  ['async', 'scala']
# 49089908  :  ['rails', 'problems']
# 51391584  :  ['change']
# 51611301  :  ['change']
# 49831638  :  ['via']
# 49226747  :  ['setting']
# 50456974  :  ['setting', 'up']
# 49972778  :  ['bash']
# 50729242  :  ['nodejs']
# 51880270  :  ['last']
# 48324958  :  ['last']
# 48965928  :  ['problems', 'macos']
# 49349682  :  ['macos']
# 49768674  :  ['azure', 'bot', 'bot']
# 48699533  :  ['version']
# 51694839  :  ['version']
# 48173304  :  ['version']
# 48824948  :  ['tests']
# 50854537  :  ['being']
# 51089154  :  ['models']
# 51928555  :  ['number']
# 49007262  :  ['number']
# 49465454  :  ['program']
