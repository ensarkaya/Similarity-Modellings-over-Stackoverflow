# %% [markdown]
# <a href="https://colab.research.google.com/github/ensarkaya/CS425-Group7-TermProject/blob/master/1millionCounter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
from collections import defaultdict
import nltk
from nltk.corpus import stopwords
path = '1millionLines.csv'
df = pd.read_csv(path)
nltk.download('stopwords')
dummy =["and","or","is","are","what","where","who","whom","when","in"
            ,"a","an","of","to","for","from","by","can","i","with","its",
             "there","that","thats","all","does","do","did","the","am","using",
             "trying","how","be","not","doesn't","don't","didn't","won't","will",
             "my","be","should","would","as","use","must","have","but","however",
             "another","other","one","two","three","four","five","still","on","why","it"
              ,"how","a","to","'",".",",",";",":","?","!","-","_"]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df["title"] = df["title"].apply(lambda x: x.lower())
stop = stopwords.words('english')
stop.append(dummy)

df["title"] = df["title"].str.split(' ').apply(lambda x: ' '.join(k for k in x if k not in dummy))

dic = {}
def has_key_with_some_values(d, key):
    return d.has_key(key) and d[key]
def get_values_if_any(d, key):
    return d.get(key, [])
for i in range(1000000):
  str = df.loc[i,'title'].split()
  for j in range(len(str)):
    if str[j] in dic:
      dic[str[j]].append(df.loc[i,'id'])
    else:
      dic[str[j]]=[df.loc[i,'id']]
print(dic['java'])
dic2={}
for i in dic:
  count=0
  for j in dic[i]:
    count+=1
  dic2[i]=count
  if count>10000:
    print(i,": ",count)
# Out:
# [49627690, 48938224, 49636971, 48654075, 50942871, 48621563, 49898963, 49795610, 50148842, 49456009, 50156012, 48900368, 51958414, 48128781, 50286871, 48568642, 49150919, 49204694, 48544238, 51443788, 49400806, 50831593, 50411064, 50411064, 51166536, 50816369, 50051157, 48779404, 48952670, 48683340, 49741015, 48583037, 49344715, 48440921, 49218986, 50740335, 50994032, 50503976, 48229476, 48945122, 48496862, 49994991, 49918691, 49282267, 51166917, 50220469, 49881225, 50864660, 49212309, 48267403, 51146317, 51963057, 51273671, 50314651, 48256736, 51084183, 49891623, 48182683, 49984232, 50760404, 51776005, 49361383, 48141087, 48902083, 49535824, 51037173, 50644357, 49811474, 51581072, 51491892, 51131004, 48168618, 48265056, 49649580, 50889519, 49299493, 52108349, 50305650, 51627511, 49765301, 51367665, 49352550, 50145929, 48402198, 50811339, 48737043, 48681647, 51587688, 49088901, 51999145, 49493619, 49458824, 49797242, 48521275, 49558508, 50679428, 51444628, 49316355, 50708490, 51457093, 49578311, 49826647, 51687977, 51687977, 49580802, 50975073, 51338084, 50831526, 51377950, 48484617, 51064914, 49179537, 48975718, 51880667, 51590111, 50495522, 51452785, 50888562, 48363600, 49154257, 52028555, 50594490, 51090645, 50142450, 51755909, 49522164, 50578027, 52098502, 49781503, 49912456, 51932627, 48643944, 51465913, 51856137, 49237984, 50622084, 51338027, 48476329, 48887802, 48060773, 52037510, 50395172, 49665608, 51633904, 48188951, 51877675, 51024146, 49742972, 50942981, 49735245, 50142108, 49183415, 51336975, 51570090, 51836028, 51715164, 51593711, 50036207, 48339967, 48235456, 50141730, 48823070, 48970305, 51177840, 51905654, 51399668, 51343930, 49285792, 49310132, 50499573, 49491226, 51441962, 49659691, 51330936, 49644897, 49400975, 50387045, 48325178, 48108426, 50303678, 51592121, 50953719, 51438109, 49530717, 51163199, 50249645, 51348909, 49422178, 51015027, 50363963, 50259030, 51063416, 50177608, 51521625, 49089124, 49704297, 50143324, 51757190, 49153331, 48711050, 51323608, 51676189, 50005134, 48174633, 50269138, 50008854, 49934485, 51092071, 48433989, 50667235, 49916178, 51002709, 50257050, 51256083, 51272819, 49845196, 50456566, 50756652, 50249830, 51410673, 49731253, 51502819, 49182390, 50387476, 51500803, 49039665, 50447066, 48115651, 50903028, 48801537, 48620581, 52061961, 48083017, 51416925, 49096476, 50593924, 50593924, 51571843, 51879946, 50897247, 50642865, 50838408, 49102553, 51782512, 51039675, 49166864, 49490087, 51861461, 51439527, 48406302, 49510006, 49221628, 48810943, 48401216, 50610414, 52091163, 50943144, 50224188, 50836704, 50081872, 48889773, 50653292, 48893154, 48389463, 50738399, 49358669, 49916497, 50380143, 48651909, 49574664, 50779512, 49315668, 51065909, 48905291, 48086678, 51920552, 50138809, 49136431, 48168485, 50572296, 51876651, 49889510, 50592095, 48637771, 50106078, 49276773, 51859700, 49230052, 51039982, 48084636, 51104270, 51148999, 50073540, 50704130, 49029400, 51123920, 51932451, 49673744, 51172413, 49915542, 49513317, 49201683, 51545560, 51910010, 48421721, 50520947, 50075916, 48837312, 49190170, 48782199, 50239000, 48920965, 49255908, 50502759, 51840873, 51253708, 49683360, 51620450, 51870003, 50369980, 49766881, 51321470, 48978086, 49309074, 50127937, 48947023, 49905750, 49129220, 48955040, 48609453, 49361744, 51273490, 48470796, 51910144, 49497778, 50766462, 50977030, 51310875, 48251990, 49726147, 49487144, 50468797, 49320820, 49218473, 49658542, 49999270, 50962549, 48531761, 51251864, 51796787, 50433947, 51725518, 49508284, 51967581, 48555465, 51425993, 51438263, 48435406, 50109849, 48248361, 50188596, 49247440, 52110023, 49953639, 50440015, 49464706, 51481486, 51240455, 51400797, 51573150, 48765274, 48649967, 51006532, 50563991, 51578907, 49613420, 49440170, 51502427, 49708641, 48334041, 48620439, 50003514, 50959033, 50447863, 50000761, 48571077, 49509313, 48951726, 51626436, 49025419, 49257353, 48346623, 51645256, 50790214, 49540676, 51476324, 51476324, 50126944, 50324439, 48961124, ...
# between :  12320
# php :  16462
# method :  13225
# after :  21405
# only :  13840
# number :  10111
# getting :  12502
# class :  16187
# google :  14400
# html :  11273
# error :  43493
# value :  29918
# if :  18270
# string :  19812
# java :  16538
# multiple :  26000
# into :  18767
# this :  10572
# issue :  10218
# function :  28046
# angular :  17910
# android :  19377
# working :  21867
# object :  19523
# cannot :  12750
# sql :  16660
# get :  37054
# table :  18229
# mysql :  10928
# python :  32981
# server :  17576
# react :  12205
# different :  15420
# database :  12811
# way :  10900
# at :  10046
# inside :  11604
# loop :  10178
# c# :  11275
# data :  44345
# text :  16055
# query :  15358
# can't :  10442
# find :  12879
# run :  10328
# update :  10799
# values :  18649
# api :  18034
# custom :  13894
# based :  11688
# array :  25439
# set :  15297
# without :  13674
# code :  16476
# time :  12177
# work :  11511
# file :  39906
# type :  13416
# json :  14726
# make :  12399
# variable :  13828
# form :  10740
# page :  13234
# spring :  10827
# while :  13737
# no :  10871
# create :  17664
# list :  20603
# r :  10302
# button :  10708
# access :  12179
# image :  15491
# javascript :  15587
# add :  17408
# app :  17202
# input :  10733
# new :  11463
# column :  16291
# same :  13923
# change :  15283
# files :  12445
# user :  12335
# specific :  11284
